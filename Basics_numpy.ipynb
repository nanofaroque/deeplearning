# %% [markdown]
# <a href="https://colab.research.google.com/github/nanofaroque/deeplearning/blob/master/Basics_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
weight=.1;
def neural_network(input,weight):
  prediction=input*weight;
  return prediction;

# %%
number_of_toes=[8.5,9.5,10,9]
input=number_of_toes[0]
pred=neural_network(input,weight)
print(pred)

# %%
import numpy as np
a=np.array([0,1,2]);

# %%
print(a)

# %%
d= np.zeros((2,4))
print(d)

# %%
print (a*.1)

# %%
weight = 0.5 
input = 0.5 
goal_prediction = 0.9 
step_amount = 0.01 

def neural_network(input, weight): 
     prediction = input * weight 
     return prediction 

for iteration in range(1101): 
    prediction = neural_network(input, weight) 
    error = (prediction - goal_prediction) ** 2 

    print ("Error:" + str(error) + " Prediction:" + str(prediction)) ;

    up_prediction = neural_network(input, weight + step_amount) 
    up_error = (goal_prediction - up_prediction) ** 2 

    down_prediction = neural_network(input, weight - step_amount) 
    down_error = (goal_prediction - down_prediction) ** 2 

    if(down_error < up_error): weight = weight - step_amount 
    if(down_error > up_error): weight = weight + step_amount
# Out:
# Error:0.42250000000000004 Prediction:0.25
# Error:0.41602500000000003 Prediction:0.255
# Error:0.4096 Prediction:0.26
# Error:0.403225 Prediction:0.265
# Error:0.39690000000000003 Prediction:0.27
# Error:0.390625 Prediction:0.275
# Error:0.3844 Prediction:0.28
# Error:0.378225 Prediction:0.28500000000000003
# Error:0.3721 Prediction:0.29000000000000004
# Error:0.366025 Prediction:0.29500000000000004
# Error:0.36 Prediction:0.30000000000000004
# Error:0.354025 Prediction:0.30500000000000005
# Error:0.34809999999999997 Prediction:0.31000000000000005
# Error:0.34222499999999995 Prediction:0.31500000000000006
# Error:0.3364 Prediction:0.32000000000000006
# Error:0.33062499999999995 Prediction:0.32500000000000007
# Error:0.32489999999999997 Prediction:0.33000000000000007
# Error:0.3192249999999999 Prediction:0.3350000000000001
# Error:0.31359999999999993 Prediction:0.3400000000000001
# Error:0.30802499999999994 Prediction:0.3450000000000001
# ...
